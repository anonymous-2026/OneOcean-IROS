# %%
from visual import analyze_nc_file

nc_file = "../MOPD_pipeline/Data/Combined/combined_environment.nc"
stats, time_range = analyze_nc_file(nc_file)
# Out:
# Variables in the dataset:
# KeysView(Frozen({'so': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'thetao': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'uo': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'vo': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'zos': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'utide': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'utotal': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'vtide': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'vtotal': <xarray.Variable (time: 720, depth: 1, latitude: 240, longitude: 240)> Size: 332MB
# [41472000 values with dtype=float64], 'elevation': <xarray.Variable (latitude: 240, longitude: 240)> Size: 230kB
# [57600 values with dtype=float32], 'time': <xarray.IndexVariable 'time' (time: 720)> Size: 6kB
# array(['2024-06-01T00:00:00.000000000', '2024-06-01T01:00:00.000000000',
#        '2024-06-01T02:00:00.000000000', ..., '2024-06-30T21:00:00.000000000',
#        '2024-06-30T22:00:00.000000000', '2024-06-30T23:00:00.000000000'],
#       dtype='datetime64[ns]'), 'depth': <xarray.IndexVariable 'depth' (depth: 1)> Size: 4B
# array([0.494025], dtype=float32), 'latitude': <xarray.IndexVariable 'latitude' (latitude: 240)> Size: 2kB
# array([33.      , 32.995816, 32.991632, ..., 32.008368, 32.004184, 32.      ]), 'longitude': <xarray.IndexVariable 'longitude' (longitude: 240)> Size: 2kB
# array([-66.5     , -66.495816, -66.491632, ..., -65.508368, -65.504184,
#        -65.5     ])}))
#
# Statistical Information:
#
# Variable: so
#   Min: 5076.4752
#   Max: 5149.4782
#   Mean: 5111.7744
#   Median: 5111.8149
#   Std: 11.4220
#
# Variable: thetao
#   Min: -278.9241
#   Max: -127.5963
#   Mean: -224.3536
#   Median: -230.7918
#   Std: 33.6354
#
# Variable: uo
#   Min: -20.6695
#   Max: 38.8348
#   Mean: 2.4012
#   Median: 1.5054
#   Std: 10.4744
#
# Variable: vo
#   Min: -17.0021
#   Max: 41.3878
#   Mean: 4.2406
#   Median: 4.0330
#   Std: 9.6978
#
# Variable: zos
#   Min: -282.8224
#   Max: -265.2470
#   Mean: -272.6160
#   Median: -271.8506
#   Std: 3.3524
#
# Variable: utide
#   Min: -10.0762
#   Max: 11.8166
#   Mean: 0.0325
#   Median: -0.2026
#   Std: 4.5840
#
# Variable: utotal
#   Min: -27.1662
#   Max: 38.4952
#   Mean: 2.2710
#   Median: 1.3403
#   Std: 12.0602
#
# Variable: vtide
#   Min: -6.7266
#   Max: 6.8326
#   Mean: 0.0133
#   Median: 0.0239
#   Std: 3.0189
#
# Variable: vtotal
#   Min: -28.1445
#   Max: 39.9217
#   Mean: 4.0882
#   Median: 4.3048
#   Std: 10.7546
#
# Variable: elevation
#   Min: -5121.0000
#   Max: -4043.0000
#   Mean: -4853.9580
#   Median: -4862.0000
#   Std: 87.6455
#
# Time Range:
#   Start Time: 2024-06-01T00:00:00.000000000
#   End Time: 2024-06-30T23:00:00.000000000
#   Time Span: 2588400000000000 nanoseconds

# %% [markdown]
# ## data_stat_and_visual

# %%
import xarray as xr
from visual import plot_3d_currents

nc_file = "../MOPD_pipeline/Data/Combined/combined_environment.nc"
dataset = xr.open_dataset(nc_file)

plot_3d_currents(dataset, output_dir="output", skip=20, arrow_size=0.05, arrow_height_offset=5, arrow_alpha=0.4, arrow_head_size=10)

# %%
import numpy as np
from visual import plot_pollutant_diffusion

if __name__ == "__main__":
    lon_min, lon_max = 130, 145
    lat_min, lat_max = 30, 45
    resolution = 0.1
    lons = np.arange(lon_min, lon_max + resolution, resolution)
    lats = np.arange(lat_min, lat_max + resolution, resolution)
    lon_grid, lat_grid = np.meshgrid(lons, lats)

    days = [5, 20, 35, 55, 75, 110]
    total_days = 120
    pollutant_data = []
    pollutant_data_all_days = []

    for day in range(1, total_days + 1):
        center_lon = 135.0 + np.sin(day / 10.0)
        center_lat = 35.0 + np.cos(day / 10.0)
        scale = 1.5 + 0.5 * np.sin(day / 15.0)
        dist_lon = lon_grid - center_lon
        dist_lat = lat_grid - center_lat
        field = np.exp(-((dist_lon ** 2 + dist_lat ** 2) / (2 * scale ** 2)))
        field += 0.1 * np.random.rand(*lon_grid.shape)
        field /= field.max()
        pollutant_data_all_days.append(field)

    for d in days:
        pollutant_data.append(pollutant_data_all_days[d - 1])

    pollutant_name = "Synthetic Pollutant Diffusion"
    plot_pollutant_diffusion(lon_grid, lat_grid, pollutant_data, days, pollutant_name,
                                            pollutant_data_all_days)

# %%
import dask.dataframe as dd

print("Step 1: Reading CSV with selected columns and dtype handling...")
file_path = '/Users/a1234/Desktop/workspace/A Large-Scale Oceanographic Dataset for Machine Learning-Based Ocean Current and Pollution Prediction/MOPD_pipeline/Data/GMB/Global_Marine_Biodiversity_Records_All.csv'

keep_columns = [
    'eventDate', 'year', 'month', 'day', 'latitude', 'longitude', 'depth',
    'country', 'countryCode', 'locality', 'continent', 'waterBody',
    'temperature', 'salinity', 'ugo', 'vgo', 'waveVelocity', 'chlorophyll',
    'nitrate', 'phosphate', 'silicate', 'dissolvedMolecularOxygen', 'nppv',
    'dissolvedIron', 'spCO2', 'ph', 'phytoplanktonExpressedAsCarbon'
]

dtypes = {col: 'object' for col in keep_columns}
df = dd.read_csv(file_path, usecols=keep_columns, dtype=dtypes)

print("Step 2: Converting numeric columns...")
numeric_cols = [
    'latitude', 'longitude', 'depth', 'temperature', 'salinity',
    'ugo', 'vgo', 'waveVelocity', 'chlorophyll', 'nitrate', 'phosphate',
    'silicate', 'dissolvedMolecularOxygen', 'nppv', 'dissolvedIron',
    'spCO2', 'ph', 'phytoplanktonExpressedAsCarbon'
]
for col in numeric_cols:
    df[col] = dd.to_numeric(df[col], errors='coerce')

print("Step 3: Dropping duplicates...")
df = df.drop_duplicates()

print("Step 4: Saving as partitioned Parquet files...")
df.to_parquet('cleaned_marine_dataset_parts/', engine='pyarrow', write_index=False)

print("Finished: Output saved in folder 'cleaned_marine_dataset_parts/'.")
# Out:
# Step 1: Reading CSV with selected columns and dtype handling...
# ERROR! Session/line number was not unique in database. History logging moved to new session 431
# Step 2: Converting numeric columns...
# Step 3: Dropping duplicates...
# Step 4: Saving as partitioned Parquet files...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 31
#      28 df = df.drop_duplicates()
#      30 print("Step 4: Saving as partitioned Parquet files...")
# ---> 31 df.to_parquet('cleaned_marine_dataset_parts/', engine='pyarrow', write_index=False)
#      33 print("Finished: Output saved in folder 'cleaned_marine_dataset_parts/'.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/dask/dataframe/core.py:5646, in DataFrame.to_parquet(self, path, *args, **kwargs)
#    5643 """See dd.to_parquet docstring for more information"""
#    5644 from dask.dataframe.io import to_parquet
# -> 5646 return to_parquet(self, path, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py:1049, in to_parquet(df, path, engine, compression, write_index, append, overwrite, ignore_divisions, partition_on, storage_options, custom_metadata, write_metadata_file, compute, compute_kwargs, schema, name_function, filesystem, **kwargs)
#    1046 out = Scalar(graph, final_name, "")
#    1048 if compute:
# -> 1049     out = out.compute(**compute_kwargs)
#    1051 # Invalidate the filesystem listing cache for the output path after write.
#    1052 # We do this before returning, even if `compute=False`. This helps ensure
#    1053 # that reading files that were just written succeeds.
#    1054 fs.invalidate_cache(path)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/dask/base.py:372, in DaskMethodsMixin.compute(self, **kwargs)
#     348 def compute(self, **kwargs):
#     349     """Compute this dask collection
#     350
#     351     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     370     dask.compute
#     371     """
# --> 372     (result,) = compute(self, traverse=False, **kwargs)
#     373     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:334, in Condition.wait(self, timeout)
#     332 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     333     if timeout is None:
# --> 334         waiter.acquire()
#     335         gotit = True
#     336     else:
#
# KeyboardInterrupt:
